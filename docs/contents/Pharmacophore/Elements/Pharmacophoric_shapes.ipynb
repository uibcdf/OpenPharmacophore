# %% [markdown]
# # Shapes

# %%
from openpharmacophore.pharmacophoric_elements import shapes
import pyunitwizard as puw
import nglview as nv

# %% [markdown]
# ## Point

# %%
position = puw.quantity([0,0,0], 'nm')
shape = shapes.Point(position)

# %%
view = nv.NGLWidget()
shape.add_to_NGLView(view, feature_name='Name of feature', color='#004777', opacity=0.5)
view.control.zoom(0.8)
view
# Out:
# NGLWidget()

# %%
view.render_image()
# Out:
# Image(value=b'', width='99%')

# %%
view._display_image()

# %% [markdown]
# ## Sphere

# %%
center = puw.quantity([0,0,0], 'nm')
radius = puw.quantity(2.0, 'nm')
shape = shapes.Sphere(center, radius)

# %%
view = nv.NGLWidget()
shape.add_to_NGLView(view, feature_name='Name of feature', color='#004777', opacity=0.5)
view.control.zoom(0.8)
view
# Out:
# NGLWidget()

# %%
view.render_image()
# Out:
# Image(value=b'', width='99%')

# %%
view._display_image()

# %% [markdown]
# ## Sphere and vector

# %%
center = puw.quantity([0,0,0], 'nm')
radius = puw.quantity(2.0, 'nm')
direction = [1,1,1]
shape = shapes.SphereAndVector(center, radius, direction)

# %%
view = nv.NGLWidget()
shape.add_to_NGLView(view, feature_name='Name of feature', color='#004777', opacity=0.5)
view.control.zoom(0.8)
view
# Out:
# NGLWidget()

# %%
view.render_image()
# Out:
# Image(value=b'', width='99%')

# %%
view._display_image()

# %% [markdown]
# ## Gaussian kernel

# %%
center = puw.quantity([0,0,0], 'nm')
sigma = puw.quantity(1.0, 'nm')
shape = shapes.GaussianKernel(center, sigma)

# %%
view = nv.NGLWidget()
shape.add_to_NGLView(view, feature_name='Name of feature', color='#004777', opacity=0.5)
view.control.zoom(0.8)
view
# Out:
# NGLWidget()

# %%
view.render_image()
# Out:
# Image(value=b'', width='99%')

# %%
view._display_image()

# %% [markdown]
# ## Shapelet

# %%
shapelet = shapes.Shapelet()
